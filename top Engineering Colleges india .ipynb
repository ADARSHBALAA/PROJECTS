# %% [markdown]
# # Top Engineering Colleges india
#
# ### Analysis of the Indian college and ranking 2022

# %% [markdown]
# #####  India is 2nd world's largest population country and every year lacks student get their college degree from various institutes in India I scrap a website containing the top 200 colleges in India in 2022, a dataset containing a list of colleges from rank 1 to 200 and some other features,

# %% [markdown]
# the feature is explained below:-
#
# 1)rank:- 1-200 ranking of the college according to different parameters
#
# 2)name:- the name of the respective college
#
# 3)ownership:- which organization own the college there are two values either public or private
#
# 4)grade:- the grade of college higher count of 'A' the good score will max(5)
#
# 5)TLR(Teaching-learning resources)= define resources as materials used by a teacher to supplement classroom instruction or to stimulate the interest of learners in simple quality content delivered to students.
#
# 6)RPC(Research and Professional Practice) developing knowledge and experience, which are standard within a field or profession, and involves information-gathering procedures that are a part of the typical relationship between practitioners
#
# 7)GO(graduation Outcome)= to understand whether recent graduates are in employment, have continued with further study or are doing something else
#
# 8)OI(outreach and inclusivity)=> it contains the following factors the number of students from another state or countries, per cent of women, facility for physically challenged student
#
# 9)perc(peer perception):- college perception in the market, stakeholder, facility perception, student perception, perception of other universities for you.
#
# 10)total:- overall percentage
#
# if you have any difficulty in any of the features please visit the link NIRF]
#
# (https://www.nirfindia.org/parameter)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import LinearSVR
import regex as re

# %%
data = pd.read_csv("200_top_Engineering_Colleges_india.csv")

# %%
data
# Out:
#      Unnamed: 0  rank                                               name  \
# 0             0     1        IIT Madras - Indian Institute of Technology
# 1             1     2         IIT Delhi - Indian Institute of Technology
# 2             2     3        IIT Bombay - Indian Institute of Technology
# 3             3     4        IIT Kanpur - Indian Institute of Technology
# 4             4     5     IIT Kharagpur - Indian Institute of Technology
# ..          ...   ...                                                ...
# 195         195   196             KLE Technological University, Hubballi
# 196         196   197  DJSCE Mumbai - Dwarkadas J Sanghvi College of ...
# 197         197   198  SVCET Chittoor - Sri Venkateswara College of E...
# 198         198   199  BMSIT Bangalore - BMS Institute of Technology ...
# 199         199   200  VJIT Hyderabad - Vidya Jyothi Institute of Tec...
#
#             owner_ship  grade    TLR    RPC     go     oi   perc  total
# 0    Public/Government  AAAAA  94.62  97.66  80.42  62.85  100.0  90.04
# 1    Public/Government  AAAAA  86.95  96.00  83.43  68.56  96.92  88.12
# 2    Public/Government  AAAAA  87.53  90.82  79.18  57.36   88.7  83.96
# 3    Public/Government  AAAAA  87.95  79.98  89.71  59.47  83.01  82.56
# 4    Public/Government  AAAAA  79.21  84.61  80.91  53.09  82.63  78.89
# ..                 ...    ...    ...    ...    ...    ...    ...    ...
# 195            Private    AAA  51.27  10.37  50.84  48.30   4.14   33.9
# 196            Private   AAAA  53.37   6.11  58.32  42.72   1.08  33.88
# 197            Private    AAA  51.15   1.54  59.07  58.37   3.14  33.77
# 198            Private   AAAA  46.40   4.77  56.46  54.39   16.8  33.76
# 199            Private    AAA  57.93   2.81  46.59  55.46   6.07   33.7
#
# [200 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   rank        200 non-null    int64
#  2   name        200 non-null    object
#  3   owner_ship  200 non-null    object
#  4   grade       200 non-null    object
#  5   TLR         200 non-null    float64
#  6   RPC         200 non-null    float64
#  7   go          200 non-null    float64
#  8   oi          200 non-null    float64
#  9   perc        200 non-null    object
#  10  total       200 non-null    object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 17.3+ KB

# %%
data.describe().T
# Out:
#             count       mean        std    min      25%      50%       75%  \
# Unnamed: 0  200.0   99.50000  57.879185   0.00  49.7500   99.500  149.2500
# rank        200.0  100.50000  57.879185   1.00  50.7500  100.500  150.2500
# TLR         200.0   58.84295  13.622641   1.47  53.4150   58.990   65.5275
# RPC         200.0   26.69360  20.207501   1.50  11.4675   19.405   37.0025
# go          200.0   58.41160  10.960065  30.12  50.8200   57.645   64.8875
# oi          200.0   54.07145   7.797928  34.99  49.2075   53.410   59.0150
#
#                max
# Unnamed: 0  199.00
# rank        200.00
# TLR          94.62
# RPC          97.66
# go           90.12
# oi           79.48

# %%
data.shape
# Out:
# (200, 11)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# rank          0
# name          0
# owner_ship    0
# grade         0
# TLR           0
# RPC           0
# go            0
# oi            0
# perc          0
# total         0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'rank', 'name', 'owner_ship', 'grade', 'TLR', 'RPC', 'go',
#        'oi', 'perc', 'total'],
#       dtype='object')

# %%
data.drop(columns="Unnamed: 0", inplace=True)

# %%
data.head()
# Out:
#    rank                                            name         owner_ship  \
# 0     1     IIT Madras - Indian Institute of Technology  Public/Government
# 1     2      IIT Delhi - Indian Institute of Technology  Public/Government
# 2     3     IIT Bombay - Indian Institute of Technology  Public/Government
# 3     4     IIT Kanpur - Indian Institute of Technology  Public/Government
# 4     5  IIT Kharagpur - Indian Institute of Technology  Public/Government
#
#    grade    TLR    RPC     go     oi   perc  total
# 0  AAAAA  94.62  97.66  80.42  62.85  100.0  90.04
# 1  AAAAA  86.95  96.00  83.43  68.56  96.92  88.12
# 2  AAAAA  87.53  90.82  79.18  57.36   88.7  83.96
# 3  AAAAA  87.95  79.98  89.71  59.47  83.01  82.56
# 4  AAAAA  79.21  84.61  80.91  53.09  82.63  78.89

# %% [markdown]
# #### list of govt colleges

# %%
govt_colleges=data.query("owner_ship =='Public/Government'" )

# %%
govt_colleges
# Out:
#      rank                                               name  \
# 0       1        IIT Madras - Indian Institute of Technology
# 1       2         IIT Delhi - Indian Institute of Technology
# 2       3        IIT Bombay - Indian Institute of Technology
# 3       4        IIT Kanpur - Indian Institute of Technology
# 4       5     IIT Kharagpur - Indian Institute of Technology
# ..    ...                                                ...
# 177   178  SLIET Longowal - Sant Longowal Institute of En...
# 181   182  RGIPT Amethi - Rajiv Gandhi Institute of Petro...
# 183   184  IIITDM Kancheepuram - Indian Institute of Info...
# 189   190  IITRAM Ahmedabad - Institute of Infrastructure...
# 193   194       NIT Delhi - National Institute of Technology
#
#             owner_ship  grade    TLR    RPC     go     oi   perc  total
# 0    Public/Government  AAAAA  94.62  97.66  80.42  62.85  100.0  90.04
# 1    Public/Government  AAAAA  86.95  96.00  83.43  68.56  96.92  88.12
# 2    Public/Government  AAAAA  87.53  90.82  79.18  57.36   88.7  83.96
# 3    Public/Government  AAAAA  87.95  79.98  89.71  59.47  83.01  82.56
# 4    Public/Government  AAAAA  79.21  84.61  80.91  53.09  82.63  78.89
# ..                 ...    ...    ...    ...    ...    ...    ...    ...
# 177  Public/Government    AAA  57.44  18.52  30.12  60.83   3.14   35.2
# 181  Public/Government    AAA   7.04  54.21  43.96  34.99
# 183  Public/Government   AAAA  36.37  13.15  62.59  51.36  24.12  34.93
# 189  Public/Government    AAA  54.88  20.07  40.44  37.21   1.08  34.41
# 193  Public/Government   AAAA  41.60  22.60  44.71  42.73  14.94  33.96
#
# [90 rows x 10 columns]

# %% [markdown]
# #### list of colleges with  grade AAAAA

# %%
grade_AAAAA=data.query("grade== 'AAAAA'")

# %%
grade_AAAAA
# Out:
#     rank                                               name  \
# 0      1        IIT Madras - Indian Institute of Technology
# 1      2         IIT Delhi - Indian Institute of Technology
# 2      3        IIT Bombay - Indian Institute of Technology
# 3      4        IIT Kanpur - Indian Institute of Technology
# 4      5     IIT Kharagpur - Indian Institute of Technology
# 5      6       IIT Roorkee - Indian Institute of Technology
# 6      7      IIT Guwahati - Indian Institute of Technology
# 7      8  NIT Trichy - National Institute of Technology ...
# 8      9     IIT Hyderabad - Indian Institute of Technology
# 9     10  NIT Surathkal - National Institute of Technolo...
# 10    11                       Jadavpur University, Kolkata
# 11    12      VIT Vellore - Vellore Institute of Technology
# 12    13  IIT BHU - Indian Institute of Technology Banar...
# 15    16        IIT Indore - Indian Institute of Technology
# 17    18      ICT Mumbai - Institute of Chemical Technology
# 18    19             Amrita Vishwa Vidyapeetham, Coimbatore
# 19    20         IIT Mandi - Indian Institute of Technology
# 20    21    NIT Warangal - National Institute of Technology
# 21    22         IIT Ropar - Indian Institute of Technology
# 22    23   IIT Gandhinagar - Indian Institute of Technology
# 28    29  BITS Pilani - Birla Institute of Technology an...
# 29    30       IIT Jodhpur - Indian Institute of Technology
# 30    31     NIT Calicut - National Institute of Technology
# 31    32  VNIT Nagpur - Visvesvaraya National Institute ...
# 35    36   IIT Bhubaneswar - Indian Institute of Technology
# 39    40  IIEST Shibpur - Indian Institute of Engineerin...
# 40    41  SASTRA University Thanjavur - Shanmugha Arts S...
# 42    43  IIST Thiruvananthapuram - Indian Institute of ...
# 46    47  MNNIT Allahabad - Motilal Nehru National Insti...
# 47    48  SSN College of Engineering - Sri Sivasubramani...
# 54    55      MIT Manipal - Manipal Institute of Technology
# 61    62  IIIT Hyderabad - International Institute of In...
# 77    78  IIITM Gwalior - Atal Bihari Vajpayee Indian In...
#
#            owner_ship  grade    TLR    RPC     go     oi   perc  total
# 0   Public/Government  AAAAA  94.62  97.66  80.42  62.85  100.0  90.04
# 1   Public/Government  AAAAA  86.95  96.00  83.43  68.56  96.92  88.12
# 2   Public/Government  AAAAA  87.53  90.82  79.18  57.36   88.7  83.96
# 3   Public/Government  AAAAA  87.95  79.98  89.71  59.47  83.01  82.56
# 4   Public/Government  AAAAA  79.21  84.61  80.91  53.09  82.63  78.89
# 5   Public/Government  AAAAA  75.98  78.10  90.12  63.09  61.36   76.7
# 6   Public/Government  AAAAA  75.89  72.89  84.64  56.90  57.15  72.98
# 7   Public/Government  AAAAA  76.39  58.43  79.16  64.49  64.38  69.17
# 8   Public/Government  AAAAA  80.32  59.89  72.39  54.85  59.96  68.03
# 9   Public/Government  AAAAA  72.87  56.42  77.69  63.89  53.24  66.04
# 10  Public/Government  AAAAA  71.38  64.41  78.11  52.33  40.97  65.68
# 11            Private  AAAAA  62.53  73.30  69.44  59.27   49.6  65.53
# 12  Public/Government  AAAAA  62.62  57.25  81.72  56.06  55.89  63.51
# 15  Public/Government  AAAAA  76.28  56.75  70.39  52.48  24.43  61.68
# 17  Public/Government  AAAAA  76.45  56.99  69.53  54.58  19.95   61.4
# 18            Private  AAAAA  68.97  58.64  61.39  61.77  41.78  60.92
# 19  Public/Government  AAAAA  75.76  44.05  77.55  67.16  22.57  60.43
# 20  Public/Government  AAAAA  73.99  45.70  75.12  54.91  35.77   60.0
# 21  Public/Government  AAAAA  81.06  38.78  68.75  63.67  30.87  59.16
# 22  Public/Government  AAAAA  80.19  39.08  64.63  60.47  35.07  58.27
# 28            Private  AAAAA  60.84  46.29  78.27  54.20  36.91   56.9
# 29  Public/Government  AAAAA  78.42  34.92  74.41  66.44  11.78   56.7
# 30  Public/Government  AAAAA  67.13  36.30  76.86  63.72  38.88  56.66
# 31  Public/Government  AAAAA  66.38  48.85  75.64  53.15  16.07  56.62
# 35  Public/Government  AAAAA  70.09  36.90  70.00  60.78  29.29  55.11
# 39  Public/Government  AAAAA  60.11  48.02  67.41  48.26  38.23  54.57
# 40            Private  AAAAA  70.01  40.17  67.29  55.94  12.59  53.36
# 42  Public/Government  AAAAA  75.78  25.35  62.60  61.97  33.15  52.37
# 46  Public/Government  AAAAA  59.01  37.99  75.22  52.15  18.23  51.17
# 47            Private  AAAAA  63.78  37.31  63.41  52.63  22.25   50.5
# 54            Private  AAAAA  67.36  33.36  49.48  62.47  19.61  48.33
# 61            Private  AAAAA  49.16  38.57  63.99  51.02  21.93  46.41
# 77  Public/Government  AAAAA  52.59  20.54  71.53  56.11    7.0  42.56

# %% [markdown]
# #### list of colleges with  grade AA

# %%
grade_AA=data.query("grade== 'AA'")

# %%
grade_AA
# Out:
#      rank                                               name  \
# 128   129  JNTUK Kakinada - Jawaharlal Nehru Technologica...
#
#             owner_ship grade    TLR    RPC     go     oi  perc  total
# 128  Public/Government    AA  57.01  19.32  47.56  50.19  3.65  37.79

# %% [markdown]
# ploted outreach & inclusivity  and graduation Outcome with bar plot method

# %%
plt.figure(figsize=(20,5))
sns.barplot(data =data, x=data.oi, y=data.go);

# %% [markdown]
# ploted teaching-learning resources and Research and Professional Practice with line plot method

# %%
plt.figure(figsize=(14,4),)
sns.lineplot(data = data, x=data.TLR, y=data.RPC);

# %% [markdown]
# ploted outreach & inclusivity  and graduation Outcome with line plot method

# %%
plt.figure(figsize=(14,4))
sns.lineplot(data = data, x=data.go, y=data.oi);

# %% [markdown]
# box ploted
#
# rank
#
# Teaching-learning resources
#
# Research and Professional Practice
#
# graduation Outcome
#
# outreach and inclusivity

# %%
for i in data.columns:
    if data[i].dtype!= "object":
        sns.boxplot(y=data[i])
        plt.show()

# %% [markdown]
# hist ploted
#
# rank
#
# Teaching-learning resources
#
# Research and Professional Practice
#
# graduation Outcome
#
# outreach and inclusivity

# %%
data.hist(figsize=(16,10),color='red');

# %% [markdown]
# ratio of ownership
#
# Public/Government and private

# %%
grade= data.groupby(['owner_ship'])['TLR'].sum()

# %%
sns.set_style('ticks')
grade.plot.pie()
plt.legend()
plt.show()

# %% [markdown]
# factor plot data of ownership withrespect to Teaching-learning resources

# %%
 sns.set_style('ticks')
sns.factorplot('owner_ship','TLR', hue='oi',data=data)
plt.show()

# %% [markdown]
# ownership data hoist plotted

# %%
sns.histplot(data.owner_ship,color='green')
plt.show()

# %% [markdown]
# hist plot - grade

# %%
sns.histplot(data.grade,color='red')
plt.show()

# %% [markdown]
# hist plot -Teaching-learning resources

# %%
sns.histplot(data.TLR,color='green')
plt.show()

# %% [markdown]
# hist plot -Research and Professional Practice

# %%
sns.histplot(data.RPC,color='purple')
plt.show()

# %% [markdown]
# hist plot -graduation Outcome

# %%
sns.histplot(data.go,color='orange')
plt.show()

# %% [markdown]
# hist plot - outreach and inclusivity

# %%
sns.histplot(data.oi,color='yellow')
plt.show()

# %% [markdown]
# hist plot - peer perception

# %%
sns.histplot(data.perc,color='blue')
plt.show()

# %% [markdown]
# pair plot of data

# %%
sns.pairplot(data=data)
plt.show()

# %% [markdown]
# heat map of data

# %%
plt.figure(figsize=(10,10))
heat_map=data.corr()
sns.heatmap(heat_map,vmin=-1,vmax=1,annot=True, linewidth=10)
plt.show()

# %% [markdown]
# box ploted
#
# rank
#
# Teaching-learning resources
#
# Research and Professional Practice
#
# graduation Outcome
#
# outreach and inclusivity

# %%
for column in data.columns:
    if data[column].dtype != "object":
        plt.figure()
        data.boxplot([column])

# %%
data
# Out:
#      rank                                               name  \
# 0       1        IIT Madras - Indian Institute of Technology
# 1       2         IIT Delhi - Indian Institute of Technology
# 2       3        IIT Bombay - Indian Institute of Technology
# 3       4        IIT Kanpur - Indian Institute of Technology
# 4       5     IIT Kharagpur - Indian Institute of Technology
# ..    ...                                                ...
# 195   196             KLE Technological University, Hubballi
# 196   197  DJSCE Mumbai - Dwarkadas J Sanghvi College of ...
# 197   198  SVCET Chittoor - Sri Venkateswara College of E...
# 198   199  BMSIT Bangalore - BMS Institute of Technology ...
# 199   200  VJIT Hyderabad - Vidya Jyothi Institute of Tec...
#
#             owner_ship  grade    TLR    RPC     go     oi   perc  total
# 0    Public/Government  AAAAA  94.62  97.66  80.42  62.85  100.0  90.04
# 1    Public/Government  AAAAA  86.95  96.00  83.43  68.56  96.92  88.12
# 2    Public/Government  AAAAA  87.53  90.82  79.18  57.36   88.7  83.96
# 3    Public/Government  AAAAA  87.95  79.98  89.71  59.47  83.01  82.56
# 4    Public/Government  AAAAA  79.21  84.61  80.91  53.09  82.63  78.89
# ..                 ...    ...    ...    ...    ...    ...    ...    ...
# 195            Private    AAA  51.27  10.37  50.84  48.30   4.14   33.9
# 196            Private   AAAA  53.37   6.11  58.32  42.72   1.08  33.88
# 197            Private    AAA  51.15   1.54  59.07  58.37   3.14  33.77
# 198            Private   AAAA  46.40   4.77  56.46  54.39   16.8  33.76
# 199            Private    AAA  57.93   2.81  46.59  55.46   6.07   33.7
#
# [200 rows x 10 columns]

# %%
data.describe(include="all").T
# Out:
#             count unique                                          top freq  \
# rank        200.0    NaN                                          NaN  NaN
# name          200    200  IIT Madras - Indian Institute of Technology    1
# owner_ship    200      2                                      Private  110
# grade         200      5                                         AAAA  119
# TLR         200.0    NaN                                          NaN  NaN
# RPC         200.0    NaN                                          NaN  NaN
# go          200.0    NaN                                          NaN  NaN
# oi          200.0    NaN                                          NaN  NaN
# perc          200     89                                         3.14   10
# total         200    190                                                 4
#
#                 mean        std    min      25%     50%      75%    max
# rank           100.5  57.879185    1.0    50.75   100.5   150.25  200.0
# name             NaN        NaN    NaN      NaN     NaN      NaN    NaN
# owner_ship       NaN        NaN    NaN      NaN     NaN      NaN    NaN
# grade            NaN        NaN    NaN      NaN     NaN      NaN    NaN
# TLR         58.84295  13.622641   1.47   53.415   58.99  65.5275  94.62
# RPC          26.6936  20.207501    1.5  11.4675  19.405  37.0025  97.66
# go           58.4116  10.960065  30.12    50.82  57.645  64.8875  90.12
# oi          54.07145   7.797928  34.99  49.2075   53.41   59.015  79.48
# perc             NaN        NaN    NaN      NaN     NaN      NaN    NaN
# total            NaN        NaN    NaN      NaN     NaN      NaN    NaN

# %%
grade_AAA=data.query("grade== 'AAAAA' & TLR >= 80 ")

# %%
grade_AAA
# Out:
#     rank                                              name         owner_ship  \
# 0      1       IIT Madras - Indian Institute of Technology  Public/Government
# 1      2        IIT Delhi - Indian Institute of Technology  Public/Government
# 2      3       IIT Bombay - Indian Institute of Technology  Public/Government
# 3      4       IIT Kanpur - Indian Institute of Technology  Public/Government
# 8      9    IIT Hyderabad - Indian Institute of Technology  Public/Government
# 21    22        IIT Ropar - Indian Institute of Technology  Public/Government
# 22    23  IIT Gandhinagar - Indian Institute of Technology  Public/Government
#
#     grade    TLR    RPC     go     oi   perc  total
# 0   AAAAA  94.62  97.66  80.42  62.85  100.0  90.04
# 1   AAAAA  86.95  96.00  83.43  68.56  96.92  88.12
# 2   AAAAA  87.53  90.82  79.18  57.36   88.7  83.96
# 3   AAAAA  87.95  79.98  89.71  59.47  83.01  82.56
# 8   AAAAA  80.32  59.89  72.39  54.85  59.96  68.03
# 21  AAAAA  81.06  38.78  68.75  63.67  30.87  59.16
# 22  AAAAA  80.19  39.08  64.63  60.47  35.07  58.27

# %%
grade_AAA.value_counts()
# Out:
# rank  name                                              owner_ship         grade  TLR    RPC    go     oi     perc   total
# 1     IIT Madras - Indian Institute of Technology       Public/Government  AAAAA  94.62  97.66  80.42  62.85  100.0  90.04    1
# 2     IIT Delhi - Indian Institute of Technology        Public/Government  AAAAA  86.95  96.00  83.43  68.56  96.92  88.12    1
# 3     IIT Bombay - Indian Institute of Technology       Public/Government  AAAAA  87.53  90.82  79.18  57.36  88.7   83.96    1
# 4     IIT Kanpur - Indian Institute of Technology       Public/Government  AAAAA  87.95  79.98  89.71  59.47  83.01  82.56    1
# 9     IIT Hyderabad - Indian Institute of Technology    Public/Government  AAAAA  80.32  59.89  72.39  54.85  59.96  68.03    1
# 22    IIT Ropar - Indian Institute of Technology        Public/Government  AAAAA  81.06  38.78  68.75  63.67  30.87  59.16    1
# 23    IIT Gandhinagar - Indian Institute of Technology  Public/Government  AAAAA  80.19  39.08  64.63  60.47  35.07  58.27    1
# dtype: int64

# %%
data.tail()
# Out:
#      rank                                               name owner_ship grade  \
# 195   196             KLE Technological University, Hubballi    Private   AAA
# 196   197  DJSCE Mumbai - Dwarkadas J Sanghvi College of ...    Private  AAAA
# 197   198  SVCET Chittoor - Sri Venkateswara College of E...    Private   AAA
# 198   199  BMSIT Bangalore - BMS Institute of Technology ...    Private  AAAA
# 199   200  VJIT Hyderabad - Vidya Jyothi Institute of Tec...    Private   AAA
#
#        TLR    RPC     go     oi  perc  total
# 195  51.27  10.37  50.84  48.30  4.14   33.9
# 196  53.37   6.11  58.32  42.72  1.08  33.88
# 197  51.15   1.54  59.07  58.37  3.14  33.77
# 198  46.40   4.77  56.46  54.39  16.8  33.76
# 199  57.93   2.81  46.59  55.46  6.07   33.7

# %%
sns.heatmap(data.corr()[["go"]].sort_values(by="go", ascending=False), vmin=-1, vmax=1, annot=True,cmap="autumn")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.corr()[["TLR"]].sort_values(by="TLR", ascending=False), vmin=-1, vmax=1, annot=True,cmap="autumn")
# Out:
# <AxesSubplot:>
